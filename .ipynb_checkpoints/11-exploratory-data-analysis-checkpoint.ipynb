# %% [markdown]
# # 探索性資料分析

# %% [markdown]
# 探索性資料分析是指利用描述統計和圖形表示等方式對資料進行初步調查，目的是發現模式(patterns)，偵測異常(anomalies)以及檢驗假設(assumptions)。

# %% [markdown]
# 目前並沒有十分嚴格的探索性資料分析流程。但大部分的資料可以依據以下的步驟進行：
#
# 1. 發現資料中每個Variable的型態與意義。找出或轉換了解問題所需的資料Variables。
#
# 2. 資料中是否有錯誤，例如資料重複或輸入錯誤？發生在那些Variable上？如何處理這些錯誤？
#
# 3. 資料中是否有遺漏值 (missing values)，發生在那些Variable上？如何處理這些遺漏值？
#
# 4. 根據資料的分布範圍，哪些是與其他資料大不相同的異常值(outliers)？這些異常值要如何處理？
#
# 5. 原始資料是否需要彙整？換句說，將以一筆資料**代表**一群相關的Observations。如何代表？
#
# 6. Variables有無需要進行合併？如何進行合併？
#
# 7. 形成問題的假設，從資料中發展出想要了解的問題。
#
# 8. 有必要的話，重複上面的各個步驟。

# %% [markdown]
# ## 載入套件與讀取資料

# %% [markdown]
# ### 載入套件

# %%
# 載入所需套件

import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### 讀取資料集

# %% [markdown]
# 此次分析的資料集是[線上零售資料集](https://archive.ics.uci.edu/ml/datasets/Online+Retail)。
# 這個檔案是excel格式，可以利用pandas的read_excel讀取成為資料框(data frame)。

# %%
# 讀入資料檔
df = pd.read_excel('Online Retail.xlsx')

# %% [markdown]
# ### 查看資料集的資訊

# %% [markdown]
# - 讀取的資料大小

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# 541909列(rows，紀錄)，8行(columns，欄位)

# %% [markdown]
# - 資料的欄位名稱

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
# InvoiceNo      541909 non-null object
# StockCode      541909 non-null object
# Description    540455 non-null object
# Quantity       541909 non-null int64
# InvoiceDate    541909 non-null datetime64[ns]
# UnitPrice      541909 non-null float64
# CustomerID     406829 non-null float64
# Country        541909 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# 這是一個交易發票的檔案，包含發票編號(InvoiceNo)、貨品編號(StockCode)、描述(Description)、數量(Quantity)、發票日期(InvoiceDate)、單價(UnitPrice)、顧客識別號(CustomerID)、國別(Country)等變數欄位。
# 其中，Quantity是整數資料型態，UnitPrice和CustomerID是浮點數，InvoiceDate是日期時間資料型態，其餘皆為文字。

# %% [markdown]
# - 數值類型的欄位資料的統計描述情形

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# - 日期時間資料的最大與最小值

# %% [markdown]
# 為了處理時間資料，載入datetime套件

# %%
from datetime import datetime
from datetime import date

# %%
print('最後日期', df.InvoiceDate.max(), '最前日期', df.InvoiceDate.min())
# Out:
# 最後日期 2011-12-09 12:50:00 最前日期 2010-12-01 08:26:00

# %% [markdown]
# 發票紀錄的時間超過1年

# %% [markdown]
# ### 資料的內容

# %% [markdown]
# 前五筆資料

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# 後五筆資料

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541904 2011-12-09 12:50:00       0.85     12680.0  France
# 541905 2011-12-09 12:50:00       2.10     12680.0  France
# 541906 2011-12-09 12:50:00       4.15     12680.0  France
# 541907 2011-12-09 12:50:00       4.15     12680.0  France
# 541908 2011-12-09 12:50:00       4.95     12680.0  France

# %% [markdown]
# ## 處理資料集內遺失、多餘以及可疑的資料

# %% [markdown]
# ### 遺失資料處理

# %% [markdown]
# 從df.info()的結果可以發現CustomerID缺乏相當多資料。
# 因此，首先列出CustomerID沒有資料的紀錄觀察。

# %%
df[df.CustomerID.isnull()]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 622    2010-12-01 11:52:00       0.00         NaN  United Kingdom
# 1443   2010-12-01 14:32:00       2.51         NaN  United Kingdom
# 1444   2010-12-01 14:32:00       2.51         NaN  United Kingdom
# 1445   2010-12-01 14:32:00       0.85         NaN  United Kingdom
# 1446   2010-12-01 14:32:00       1.66         NaN  United Kingdom
# ...                    ...        ...         ...             ...
# 541536 2011-12-09 10:26:00       4.13         NaN  United Kingdom
# 541537 2011-12-09 10:26:00       4.13         NaN  United Kingdom
# 541538 2011-12-09 10:26:00       4.96         NaN  United Kingdom
# 541539 2011-12-09 10:26:00      10.79         NaN  United Kingdom
# 541540 2011-12-09 10:26:00    1714.17         NaN  United Kingdom
#
# [135080 rows x 8 columns]

# %% [markdown]
# 去除CustomerID沒有資料的紀錄

# %%
df = df.dropna(subset=['CustomerID'])

# %% [markdown]
# 確認是否去除成功

# %%
df[df.CustomerID.isnull()]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %% [markdown]
# ### 多餘資料處理

# %% [markdown]
# 如前面的分析結果，發票日期在2010-12-01到2011-12-09間，稍微超過一年。
# 為了方便計算起見，取2010-12-09到2011-12-09之間的資料。

# %%
df = df[df.InvoiceDate>=datetime(2010, 12, 9, 0, 0, 0)]

# %% [markdown]
# ### 特殊資料處理

# %% [markdown]
# 查看數量(Quantity)為負或0的情形

# %%
df[df.Quantity<=0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 19802    C537893     22450          SILK PURSE BABUSHKA BLUE        -1
# 19803    C537893     22634    CHILDS BREAKFAST SET SPACEBOY         -2
# 19804    C537893     22630              DOLLY GIRL LUNCH BOX        -2
# 19994    C537998     22727         ALARM CLOCK BAKELIKE RED         -4
# 19995    C537998     22725    ALARM CLOCK BAKELIKE CHOCOLATE        -4
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 19802  2010-12-09 10:14:00       3.35     12721.0          France
# 19803  2010-12-09 10:14:00       9.95     12721.0          France
# 19804  2010-12-09 10:14:00       1.95     12721.0          France
# 19994  2010-12-09 11:42:00       3.75     17411.0  United Kingdom
# 19995  2010-12-09 11:42:00       3.75     17411.0  United Kingdom
# ...                    ...        ...         ...             ...
# 540449 2011-12-09 09:57:00       0.83     14397.0  United Kingdom
# 541541 2011-12-09 10:28:00     224.69     15498.0  United Kingdom
# 541715 2011-12-09 11:57:00      10.95     15311.0  United Kingdom
# 541716 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
# 541717 2011-12-09 11:58:00       1.25     17315.0  United Kingdom
#
# [8680 rows x 8 columns]

# %% [markdown]
# 當Quantity<=0時，該筆交易為取消，InvoiceNo的首字為C

# %%
#取出購買紀錄(不包含取消紀錄)
df_purchase = df[df.Quantity>0] 

df_purchase = df_purchase.assign(PurchaseDate=df_purchase.InvoiceDate.apply(lambda x: x.date()))

df_purchase = df_purchase.assign(Total = lambda x: x.UnitPrice*x.Quantity)

# %% [markdown]
# 查看單價(UnitPrice)為負或0的情形

# %%
df_purchase[df_purchase.UnitPrice<=0]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 33576     539263     22580         ADVENT CALENDAR GINGHAM SACK         4
# 40089     539722     22423             REGENCY CAKESTAND 3 TIER        10
# 47068     540372     22090              PAPER BUNTING RETROSPOT        24
# 47070     540372     22553               PLASTERS IN TIN SKULLS        24
# 56674     541109     22168        ORGANISER WOOD ANTIQUE WHITE          1
# 86789     543599    84535B         FAIRY CAKES NOTEBOOK A6 SIZE        16
# 130188    547417     22062  CERAMIC BOWL WITH LOVE HEART DESIGN        36
# 139453    548318     22055   MINI CAKE STAND  HANGING STRAWBERY         5
# 145208    548871     22162          HEART GARLAND RUSTIC PADDED         2
# 157042    550188     22636   CHILDS BREAKFAST SET CIRCUS PARADE         1
# 187613    553000     47566                        PARTY BUNTING         4
# 198383    554037     22619            SET OF 6 SOLDIER SKITTLES        80
# 279324    561284     22167           OVAL WALL MIRROR DIAMANTE          1
# 282912    561669     22960             JAM MAKING SET WITH JARS        11
# 285657    561916         M                               Manual         1
# 298054    562973     23157           SET OF 6 NATIVITY MAGNETS        240
# 314745    564651     23270     SET OF 2 CERAMIC PAINTED HEARTS         96
# 314746    564651     23268  SET OF 2 CERAMIC CHRISTMAS REINDEER       192
# 314747    564651     22955             36 FOIL STAR CAKE CASES        144
# 314748    564651     21786                   POLKADOT RAIN HAT        144
# 358655    568158      PADS           PADS TO MATCH ALL CUSHIONS         1
# 361825    568384         M                               Manual         1
# 379913    569716     22778                   GLASS CLOCHE SMALL         2
# 395529    571035         M                               Manual         1
# 420404    572893     21208          PASTEL COLOUR HONEYCOMB FAN         5
# 436428    574138     23234        BISCUIT TIN VINTAGE CHRISTMAS       216
# 436597    574175     22065       CHRISTMAS PUDDING TRINKET POT         12
# 436961    574252         M                               Manual         1
# 439361    574469     22385            JUMBO BAG SPACEBOY DESIGN        12
# 446125    574879     22625                   RED KITCHEN SCALES         2
# 446793    574920     22899         CHILDREN'S APRON DOLLY GIRL          1
# 446794    574920     23480       MINI LIGHTS WOODLAND MUSHROOMS         1
# 454463    575579     22437        SET OF 9 BLACK SKULL BALLOONS        20
# 454464    575579     22089        PAPER BUNTING VINTAGE PAISLEY        24
# 479079    577129     22464          HANGING METAL HEART LANTERN         4
# 479546    577168         M                               Manual         1
# 480649    577314     23407       SET OF 2 TRAYS HOME SWEET HOME         2
# 485985    577696         M                               Manual         1
# 502122    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 33576  2010-12-16 14:36:00        0.0     16560.0  United Kingdom
# 40089  2010-12-21 13:45:00        0.0     14911.0            EIRE
# 47068  2011-01-06 16:41:00        0.0     13081.0  United Kingdom
# 47070  2011-01-06 16:41:00        0.0     13081.0  United Kingdom
# 56674  2011-01-13 15:10:00        0.0     15107.0  United Kingdom
# 86789  2011-02-10 13:08:00        0.0     17560.0  United Kingdom
# 130188 2011-03-23 10:25:00        0.0     13239.0  United Kingdom
# 139453 2011-03-30 12:45:00        0.0     13113.0  United Kingdom
# 145208 2011-04-04 14:42:00        0.0     14410.0  United Kingdom
# 157042 2011-04-14 18:57:00        0.0     12457.0     Switzerland
# 187613 2011-05-12 15:21:00        0.0     17667.0  United Kingdom
# 198383 2011-05-20 14:13:00        0.0     12415.0       Australia
# 279324 2011-07-26 12:24:00        0.0     16818.0  United Kingdom
# 282912 2011-07-28 17:09:00        0.0     12507.0           Spain
# 285657 2011-08-01 11:44:00        0.0     15581.0  United Kingdom
# 298054 2011-08-11 11:42:00        0.0     14911.0            EIRE
# 314745 2011-08-26 14:19:00        0.0     14646.0     Netherlands
# 314746 2011-08-26 14:19:00        0.0     14646.0     Netherlands
# 314747 2011-08-26 14:19:00        0.0     14646.0     Netherlands
# 314748 2011-08-26 14:19:00        0.0     14646.0     Netherlands
# 358655 2011-09-25 12:22:00        0.0     16133.0  United Kingdom
# 361825 2011-09-27 09:46:00        0.0     12748.0  United Kingdom
# 379913 2011-10-06 08:17:00        0.0     15804.0  United Kingdom
# 395529 2011-10-13 12:50:00        0.0     12446.0             RSA
# 420404 2011-10-26 14:36:00        0.0     18059.0  United Kingdom
# 436428 2011-11-03 11:26:00        0.0     12415.0       Australia
# 436597 2011-11-03 11:47:00        0.0     14110.0  United Kingdom
# 436961 2011-11-03 13:24:00        0.0     12437.0          France
# 439361 2011-11-04 11:55:00        0.0     12431.0       Australia
# 446125 2011-11-07 13:22:00        0.0     13014.0  United Kingdom
# 446793 2011-11-07 16:34:00        0.0     13985.0  United Kingdom
# 446794 2011-11-07 16:34:00        0.0     13985.0  United Kingdom
# 454463 2011-11-10 11:49:00        0.0     13081.0  United Kingdom
# 454464 2011-11-10 11:49:00        0.0     13081.0  United Kingdom
# 479079 2011-11-17 19:52:00        0.0     15602.0  United Kingdom
# 479546 2011-11-18 10:42:00        0.0     12603.0         Germany
# 480649 2011-11-18 13:23:00        0.0     12444.0          Norway
# 485985 2011-11-21 11:57:00        0.0     16406.0  United Kingdom
# 502122 2011-11-25 15:57:00        0.0     13256.0  United Kingdom
#
#        PurchaseDate  Total
# 33576    2010-12-16    0.0
# 40089    2010-12-21    0.0
# 47068    2011-01-06    0.0
# 47070    2011-01-06    0.0
# 56674    2011-01-13    0.0
# 86789    2011-02-10    0.0
# 130188   2011-03-23    0.0
# 139453   2011-03-30    0.0
# 145208   2011-04-04    0.0
# 157042   2011-04-14    0.0
# 187613   2011-05-12    0.0
# 198383   2011-05-20    0.0
# 279324   2011-07-26    0.0
# 282912   2011-07-28    0.0
# 285657   2011-08-01    0.0
# 298054   2011-08-11    0.0
# 314745   2011-08-26    0.0
# 314746   2011-08-26    0.0
# 314747   2011-08-26    0.0
# 314748   2011-08-26    0.0
# 358655   2011-09-25    0.0
# 361825   2011-09-27    0.0
# 379913   2011-10-06    0.0
# 395529   2011-10-13    0.0
# 420404   2011-10-26    0.0
# 436428   2011-11-03    0.0
# 436597   2011-11-03    0.0
# 436961   2011-11-03    0.0
# 439361   2011-11-04    0.0
# 446125   2011-11-07    0.0
# 446793   2011-11-07    0.0
# 446794   2011-11-07    0.0
# 454463   2011-11-10    0.0
# 454464   2011-11-10    0.0
# 479079   2011-11-17    0.0
# 479546   2011-11-18    0.0
# 480649   2011-11-18    0.0
# 485985   2011-11-21    0.0
# 502122   2011-11-25    0.0

# %% [markdown]
# ## 資料群組彙整分析

# %% [markdown]
# - 統計各國的購買交易數(不同的發票號碼)

# %%
'''
以國家分組： groupby('Country')
依據發票編號，計算不重複的次數： [["InvoiceNo"]].nunique()
根據發票編號數量，由大到小排列： sort_values("InvoiceNo", ascending=False)
'''
df_purchase.groupby('Country')[["InvoiceNo"]].nunique().reset_index()\
.sort_values("InvoiceNo", ascending=False)
# Out:
#                  Country  InvoiceNo
# 34        United Kingdom      16017
# 14               Germany        445
# 13                France        382
# 10                  EIRE        252
# 3                Belgium         97
# 22           Netherlands         94
# 29                 Spain         89
# 0              Australia         55
# 25              Portugal         54
# 31           Switzerland         50
# 12               Finland         41
# 18                 Italy         37
# 30                Sweden         36
# 23                Norway         34
# 6        Channel Islands         26
# 24                Poland         18
# 9                Denmark         18
# 19                 Japan         18
# 1                Austria         17
# 7                 Cyprus         16
# 35           Unspecified          8
# 28             Singapore          7
# 16               Iceland          6
# 5                 Canada          6
# 21                 Malta          5
# 17                Israel          5
# 15                Greece          5
# 32                   USA          5
# 11    European Community          4
# 33  United Arab Emirates          3
# 8         Czech Republic          2
# 2                Bahrain          2
# 20               Lebanon          1
# 26                   RSA          1
# 27          Saudi Arabia          1
# 4                 Brazil          1

# %% [markdown]
# - 統計各國上的顧客數(不同的顧客識別號)

# %%
'''
以國家分組： groupby('Country')
依據顧客編號，計算不重複的次數： [["CustomerID"]].nunique()
根據顧客編號數量，由大到小排列： sort_values("CustomerID", ascending=False)
'''
df_purchase.groupby('Country')[["CustomerID"]].nunique().reset_index()\
.sort_values("CustomerID", ascending=False)
# Out:
#                  Country  CustomerID
# 34        United Kingdom        3863
# 14               Germany          93
# 13                France          85
# 29                 Spain          30
# 3                Belgium          25
# 31           Switzerland          21
# 25              Portugal          19
# 18                 Italy          13
# 12               Finland          12
# 1                Austria          11
# 23                Norway          10
# 0              Australia           9
# 9                Denmark           9
# 6        Channel Islands           9
# 22           Netherlands           8
# 30                Sweden           8
# 19                 Japan           8
# 7                 Cyprus           8
# 24                Poland           6
# 32                   USA           4
# 5                 Canada           4
# 35           Unspecified           4
# 15                Greece           4
# 10                  EIRE           3
# 17                Israel           3
# 21                 Malta           2
# 33  United Arab Emirates           2
# 2                Bahrain           2
# 20               Lebanon           1
# 8         Czech Republic           1
# 26                   RSA           1
# 27          Saudi Arabia           1
# 28             Singapore           1
# 16               Iceland           1
# 4                 Brazil           1
# 11    European Community           1

# %% [markdown]
# 以英國(United Kingdom)為此線上商店的主要銷售國家，其餘的重要國家也大都在歐洲

# %% [markdown]
# ### 查看顧客的購買次數與金額

# %% [markdown]
# 查看顧客的購買次數與金額(附註：此為RFM模式中的購買頻率'Frequency'和購買金額'Monetary')

# %% [markdown]
# - 查看顧客的購買次數

# %%
# 購買紀錄最多的前10名顧客(每一次購買紀錄為同一個發票編號)
'''
以顧客編號分組： groupby('CustomerID')
依據發票編號，計算不重複的次數： [["InvoiceNo"]].nunique()
根據發票編號數量，由大到小排列： sort_values("CustomerID", ascending=False)
'''
df_purchase.groupby('CustomerID')[["InvoiceNo"]].nunique().reset_index() \
.sort_values('InvoiceNo', ascending=False)[:10]
# Out:
#       CustomerID  InvoiceNo
# 322      12748.0        196
# 1859     14911.0        194
# 3960     17841.0        121
# 554      13089.0         94
# 1644     14606.0         90
# 2152     15311.0         88
# 475      12971.0         83
# 1672     14646.0         74
# 785      13408.0         60
# 2668     16029.0         60

# %%
- 查看顧客的購買金額

# %%
'''
以顧客編號分組： groupby('CustomerID')
計算所有發票每項貨品總價的總和： [["Total"]].sum()
根據發票的購買金額，由大到小排列： sort_values('Total', ascending=False)
'''
df_purchase.groupby('CustomerID')[["Total"]].sum().reset_index()\
.sort_values('Total', ascending=False)[:10]
# Out:
#       CustomerID      Total
# 1672     14646.0  280206.02
# 4141     18102.0  233736.93
# 3680     17450.0  192521.95
# 2971     16446.0  168472.50
# 1859     14911.0  140359.03
# 55       12415.0  124914.53
# 1319     14156.0  117057.43
# 3723     17511.0   87591.70
# 0        12346.0   77183.60
# 2668     16029.0   76753.32

# %% [markdown]
# ### 分析每天的購買紀錄

# %% [markdown]
# - 每天的購買筆數

# %%
df_purchase.groupby('PurchaseDate')[["InvoiceNo"]].nunique().reset_index()
# Out:
#     PurchaseDate  InvoiceNo
# 0     2010-12-09         98
# 1     2010-12-10         72
# 2     2010-12-12         43
# 3     2010-12-13         64
# 4     2010-12-14         81
# ..           ...        ...
# 293   2011-12-05        116
# 294   2011-12-06        110
# 295   2011-12-07        104
# 296   2011-12-08        113
# 297   2011-12-09         41
#
# [298 rows x 2 columns]

# %% [markdown]
# - 每天的購買金額

# %%
df_purchase.groupby('PurchaseDate')[["Total"]].sum().reset_index()
# Out:
#     PurchaseDate      Total
# 0     2010-12-09   38231.90
# 1     2010-12-10   33650.28
# 2     2010-12-12   17305.77
# 3     2010-12-13   27642.68
# 4     2010-12-14   29322.30
# ..           ...        ...
# 293   2011-12-05   58202.21
# 294   2011-12-06   46144.04
# 295   2011-12-07   69354.21
# 296   2011-12-08   50519.41
# 297   2011-12-09  184349.28
#
# [298 rows x 2 columns]

# %%
purchase_date = df_purchase.groupby('PurchaseDate')[["Total"]].sum().reset_index()

# %% [markdown]
# ### 將運算結果繪成圖形

# %%
'''
由於並不是每天都有發票紀錄，為了繪製線圖，產生一個包含所有日期的資料框
'''
pur = pd.date_range('2010-12-09', '2011-12-09')\
.to_frame(index=False)\
.rename(columns={0:'PurchaseDate'})\
.assign(PurchaseDate= lambda x: x.PurchaseDate.apply(lambda x: x.date()))
pur
# Out:
#     PurchaseDate
# 0     2010-12-09
# 1     2010-12-10
# 2     2010-12-11
# 3     2010-12-12
# 4     2010-12-13
# ..           ...
# 361   2011-12-05
# 362   2011-12-06
# 363   2011-12-07
# 364   2011-12-08
# 365   2011-12-09
#
# [366 rows x 1 columns]

# %%
'''
將新產生的資料框和每天的購買金額合併
'''
pur = pur.merge(purchase_date, how='left', on=['PurchaseDate'])

# %%
'''
如果當天沒有發票紀錄(PurchaseTotal是NaN)，便將當天的購買金額設為0
'''
pur.loc[pur.Total.isnull(), 'Total'] = 0

# %% [markdown]
# 將每天的購買金額畫成線圖

# %%
'''
載入繪圖套件中有關日期的部分
'''
import matplotlib.dates as mdates

# %%
'''
日期轉換所需的轉換器
'''
pd.plotting.register_matplotlib_converters() #轉換器函式庫位置

# %%
'''
圖形中有中文字型的問題
參考
https://codertw.com/%E7%A8%8B%E5%BC%8F%E8%AA%9E%E8%A8%80/359974/
'''
from matplotlib.font_manager import FontProperties

han_font = FontProperties(fname=r"c:/windows/fonts/msjh.ttc", size=14) # 中文字形

# %%
'''
設計圖形呈現的外觀風格
'''
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(10,5))
ax = sns.lineplot(data=pur, x='PurchaseDate',y='Total')

# %%
plt.figure(figsize=(10,5))
ax = sns.lineplot(data=pur, x='PurchaseDate',y='Total')
# 加上圖形上的標題
ax.set_xlabel('購買日期', fontproperties=han_font)
ax.set_ylabel('購買金額', fontproperties=han_font)
ax.set_title('每天的購買金額', fontproperties=han_font, fontsize=18)
# Out:
# Text(0.5, 1.0, '每天的購買金額')

# %%
plt.figure(figsize=(10,5))
ax = sns.lineplot(data=pur, x='PurchaseDate',y='Total')
# 加上圖形上的標題
ax.set_xlabel('購買日期', fontproperties=han_font)
ax.set_ylabel('購買金額', fontproperties=han_font)
ax.set_title('每天的購買金額', fontproperties=han_font, fontsize=18)
# 改變x軸上的主要刻度為一個月
months = mdates.MonthLocator()  # every month
ax.xaxis.set_major_locator(months)
plt.xticks(rotation=60)
# Out:
# (array([734107., 734138., 734169., 734197., 734228., 734258., 734289.,
#         734319., 734350., 734381., 734411., 734442., 734472.]),
#  <a list of 13 Text xticklabel objects>)

# %% [markdown]
# 挑選2月到五月之間的日期，查看購買金額總數是否有周期變化？

# %%
part_pur = pur[(pur.PurchaseDate>=date(2011, 2, 1)) & (pur.PurchaseDate<=date(2011, 5, 31))]

# %%
plt.figure(figsize=(10,5))
ax = sns.lineplot(data=part_pur, x='PurchaseDate',y='Total')
# 加上圖形上的標題
ax.set_xlabel('購買日期', fontproperties=han_font)
ax.set_ylabel('購買金額', fontproperties=han_font)
ax.set_title('每天的購買金額', fontproperties=han_font, fontsize=18)
# 改變x軸上的主要刻度為一個月
months = mdates.MonthLocator()  # every month
ax.xaxis.set_major_locator(months)
plt.xticks(rotation=60)
# Out:
# (array([734169., 734197., 734228., 734258., 734289.]),
#  <a list of 5 Text xticklabel objects>)

# %% [markdown]
# 探討一週間的哪一天的購買金額總數最高

# %%
pur = pur.assign(Weekday=pur.PurchaseDate.apply(lambda x: x.strftime('%a')))

# %%
g = sns.FacetGrid(pur, row="Weekday", hue="Weekday", height=2, aspect=2)
g.map(plt.hist, "Total", bins=np.arange(0, 15000, 1000))

# %%
fig, ax = plt.subplots(figsize=(20,9))
chart = sns.boxplot(data=purchase_date, x='Weekday', y='PurchaseTotal',
                    order=['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri'])

# %%
探討一天每個時段的購買金額總數

# %%
hour_purchase = df_purchase.assign(PurchaseHour=lambda x: x.InvoiceDate.dt.hour)\
.assign(PurchaseTotal=lambda x: x.UnitPrice*x.Quantity)\
.groupby('PurchaseHour')\
.PurchaseTotal.sum()\
.reset_index()

hour_purchase
# Out:
#     PurchaseHour  PurchaseTotal
# 0              6          4.250
# 1              7      30592.210
# 2              8     278196.960
# 3              9     820238.221
# 4             10    1234346.171
# 5             11    1079427.370
# 6             12    1335843.280
# 7             13    1136096.420
# 8             14     974736.821
# 9             15     931281.500
# 10            16     421118.330
# 11            17     226069.771
# 12            18     102389.930
# 13            19      48487.810
# 14            20      18932.760

# %%
fig, ax = plt.subplots(figsize=(20,9))
chart = sns.barplot(data=hour_purchase, x='PurchaseHour', y='PurchaseTotal')

# %%
每週各天的各時段購買金額

# %%
df_purchase.assign(PurchaseHour=lambda x: x.InvoiceDate.dt.hour)\
.assign(Weekday=lambda x: x.InvoiceDate.dt.strftime("%a"))\
.assign(PurchaseTotal=lambda x: x.UnitPrice*x.Quantity)\
.groupby('Weekday')\
.groupby('PurchaseHour')\
.PurchaseTotal.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-119-65472465874d> in <module>
#       2 .assign(Weekday=lambda x: x.InvoiceDate.dt.strftime("%a"))\
#       3 .assign(PurchaseTotal=lambda x: x.UnitPrice*x.Quantity)\
# ----> 4 .groupby('Weekday')\
#       5 .groupby('PurchaseHour')\
#       6 .PurchaseTotal.sum()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     561             return self[attr]
#     562         if hasattr(self.obj, attr):
# --> 563             return self._make_wrapper(attr)
#     564
#     565         raise AttributeError(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     602                 "using the 'apply' method".format(kind, name, type(self).__name__)
#     603             )
# --> 604             raise AttributeError(msg)
#     605
#     606         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'groupby' of 'DataFrameGroupBy' objects, try using the 'apply' method

# %%
依據購買金額排序商品

# %%
依據取消金額排序商品
